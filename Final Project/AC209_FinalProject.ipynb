# %%
# %matplotlib inline 
import os
import requests 
from StringIO import StringIO
import numpy as np
import pandas as pd # pandas
import matplotlib.pyplot as plt # module for plotting 
import datetime as dt # module for manipulating dates and times
import numpy.linalg as lin # module for performing linear algebra operations

# %%
#url = '/Users/zyzdiana/Dropbox/209FinalProject/H-1B_data/H-1B_Case_Data_FY2008.xlsx'
url = 'H-1B_data_CSV/H-1B_Case_Data_FY2008.csv'
#raw2008 =  pd.read_excel(url)
#newFile = pd.ExcelFile(url)

# %%
url = 'H-1B_data_CSV/'+filenames[2]
# Out:
# 'H-1B_data_CSV/H-1B_Case_Data_FY2009_2.csv'

# %%
ped =  pd.read_csv(url)
ped.head()
# Out:
# //anaconda/lib/python2.7/site-packages/pandas/io/parsers.py:1139: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)
#       LCA_CASE_NUMBER     STATUS LCA_CASE_SUBMIT Decision_Date VISA_CLASS  \
# 0  I-200-09105-016987     DENIED          5/7/09       5/13/09       H-1B
# 1  I-200-09105-052111  CERTIFIED         4/15/09       5/27/09       H-1B
# 2  I-200-09105-084817  CERTIFIED         4/15/09       5/27/09       H-1B
# 3  I-200-09105-089121  WITHDRAWN         4/20/09       6/18/09       H-1B
# 4  I-200-09105-089121  WITHDRAWN         4/20/09       6/18/09       H-1B
#
#   LCA_CASE_EMPLOYMENT_START_DATE LCA_CASE_EMPLOYMENT_END_DATE  \
# 0                         7/1/09                       7/1/12
# 1                        10/1/09                      9/30/12
# 2                         8/1/09                       8/1/12
# 3                        5/15/09                      7/14/09
# ...

# %%
filenames = os.listdir("H-1B_data_CSV")
filenames = filenames[1:8]
filenames
# Out:
# ['H-1B_Case_Data_FY2008.csv',
#  'H-1B_Case_Data_FY2009_1.csv',
#  'H-1B_Case_Data_FY2009_2.csv',
#  'H-1B_Case_Data_FY2010.csv',
#  'H-1B_Case_Data_FY2011.csv',
#  'H-1B_Case_Data_FY2012.csv',
#  'H-1B_Case_Data_FY2013.csv']

# %%
def build_frame(url):
    """
    Returns a pandas DataFrame object containing
    the data returned from the given url
    """
    
    # Use StringIO because pd.DataFrame.from_csv requires .read() method
    s = StringIO(source)
    
    return pd.DataFrame.from_csv(s, index_col=None).convert_objects(
            convert_dates="coerce", convert_numeric=True)

# %%
dfs = dict((d.split("/")[-1][:-4], build_frame(election)) for d in data_urls)

# %%
raw2008.head()
# Out:
#   SUBMITTED_DATE          CASE_NO PROGRAM  \
# 0     2008-03-30  I-08090-4182485       R
# 1     2008-03-30  I-08090-4182487       R
# 2     2008-03-30  I-08090-4182493       R
# 3     2008-03-30  I-08090-4182495       R
# 4     2008-03-30  I-08090-4182497       R
#
#                                          NAME                       ADDRESS1  \
# 0  SPI RESEARCH AND DEVELOPMENT SERVICES, LLC        67 SOUTH BEDFORD STREET
# 1               Nexus Software Solutions,Inc.  200 Lakeside Drive, Suite 228
# 2                                GREYCELL INC               3830 VILLAGE TER
# 3                            DATA PIONEER INC                 80 WALL STREET
# 4               Nexus Software Solutions,Inc.  200 Lakeside Drive, Suite 228
#
#       ADDRESS2        CITY STATE  POSTAL_CODE  NBR_IMMIGRANTS       ...        \
# 0        205 W  BURLINGTON    MA         1803               1       ...
# 1          NaN     Horsham    PA        19044               1       ...
# ...

# %%
raw2008.columns
# Out:
# Index([u'SUBMITTED_DATE', u'CASE_NO', u'PROGRAM', u'NAME', u'ADDRESS1', u'ADDRESS2', u'CITY', u'STATE', u'POSTAL_CODE', u'NBR_IMMIGRANTS', u'BEGIN_DATE', u'END_DATE', u'JOB_TITLE', u'DOL_DECISION_DATE', u'CERTIFIED_BEGIN_DATE', u'CERTIFIED_END_DATE', u'JOB_CODE', u'APPROVAL_STATUS', u'WAGE_RATE_1', u'RATE_PER_1', u'MAX_RATE_1', u'PART_TIME_1', u'CITY_1', u'STATE_1', u'PREVAILING_WAGE_1', u'WAGE_SOURCE_1', u'YR_SOURCE_PUB_1', u'OTHER_WAGE_SOURCE_1', u'WAGE_RATE_2', u'RATE_PER_2', u'MAX_RATE_2', u'PART_TIME_2', u'CITY_2', u'STATE_2', u'PREVAILING_WAGE_2', u'WAGE_SOURCE_2', u'YR_SOURCE_PUB_2', u'OTHER_WAGE_SOURCE_2', u'WITHDRAWN', u'OCCUPATIONAL_TITLE'], dtype='object')
